# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns

from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Loading Dataset

# %%
wine = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\SkillVertex\Major project\winequalityN.csv")
wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
print(wine.shape)
# Out:
# (6497, 13)

# %%
#Description
wine.describe(include='all')
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497    6487.000000       6489.000000  6494.000000     6495.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4898            NaN               NaN          NaN             NaN
# mean      NaN       7.216579          0.339691     0.318722        5.444326
# std       NaN       1.296750          0.164649     0.145265        4.758125
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.400000     0.390000        8.100000
# max       NaN      15.900000          1.580000     1.660000       65.800000
#
# ...

# %%
#Finding Null Values
print(wine.isna().sum())
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
wine1 = pd.DataFrame(wine).fillna(0)

# %%
wine1
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
print(wine1.isna().sum())
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine1.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.212576     0.320668
# volatile acidity           0.212576          1.000000    -0.377545
# citric acid                0.320668         -0.377545     1.000000
# residual sugar            -0.110573         -0.194984     0.141796
# chlorides                  0.292623          0.376288     0.038836
# free sulfur dioxide       -0.274535         -0.352004     0.132757
# total sulfur dioxide      -0.322457         -0.414812     0.194515
# density                    0.448739          0.270759     0.095693
# pH                        -0.168988          0.211092    -0.266023
# sulphates                  0.293984          0.221506     0.059221
# alcohol                   -0.093488         -0.037229    -0.009973
# quality                   -0.074060         -0.265671     0.085780
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine1.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.312208          0.389404     0.307577        5.804116
# 6             7.167913          0.313288     0.323558        5.549224
# 7             7.128962          0.288360     0.334764        4.729564
# 8             6.803109          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.059880            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054149            31.165021            115.410790  0.994558
# ...

# %% [markdown]
# # Data Analysis

# %%
#Countplot
sns.countplot(wine1['quality'])
plt.show()

# %%
sns.countplot(wine1['pH'])
plt.show()

# %%
sns.countplot(wine1['alcohol'])
plt.show()

# %%
sns.countplot(wine1['fixed acidity'])
plt.show()

# %%
sns.countplot(wine1['fixed acidity'])
plt.show()

# %%
sns.countplot(wine1['volatile acidity'])
plt.show()

# %%
sns.countplot(wine1['citric acid'])
plt.show()

# %%
sns.countplot(wine1['density'])
plt.show()

# %%
fig = plt.figure(figsize=(15,10))

plt.subplot(3,4,1)
sns.barplot(x='quality',y='fixed acidity',data=wine1)

plt.subplot(3,4,2)
sns.barplot(x='quality',y='volatile acidity',data=wine1)

plt.subplot(3,4,3)
sns.barplot(x='quality',y='citric acid',data=wine1)

plt.subplot(3,4,4)
sns.barplot(x='quality',y='residual sugar',data=wine1)

plt.subplot(3,4,5)
sns.barplot(x='quality',y='chlorides',data=wine1)

plt.subplot(3,4,6)
sns.barplot(x='quality',y='free sulfur dioxide',data=wine1)

plt.subplot(3,4,7)
sns.barplot(x='quality',y='total sulfur dioxide',data=wine1)

plt.subplot(3,4,8)
sns.barplot(x='quality',y='density',data=wine1)

plt.subplot(3,4,9)
sns.barplot(x='quality',y='pH',data=wine1)

plt.subplot(3,4,10)
sns.barplot(x='quality',y='sulphates',data=wine1)

plt.subplot(3,4,11)
sns.barplot(x='quality',y='alcohol',data=wine1)

plt.tight_layout()

# %% [markdown]
# # KDE plot

# %%
sns.kdeplot(wine1.query('quality > 2').quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %% [markdown]
# # Distplot

# %%
sns.distplot(wine1['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
wine1.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity               AxesSubplot(0.125,0.71587;0.168478x0.16413)
# volatile acidity         AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# citric acid              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# residual sugar           AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# chlorides                  AxesSubplot(0.125,0.518913;0.168478x0.16413)
# free sulfur dioxide     AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# total sulfur dioxide    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# density                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# pH                         AxesSubplot(0.125,0.321957;0.168478x0.16413)
# sulphates               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# alcohol                 AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# quality                 AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %%
wine1.plot(kind ='density',subplots = True, layout =(4,4),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %% [markdown]
# # Heatmap for expressing correlation

# %%
corr = wine1.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(wine1)

# %% [markdown]
# # Feature Selection

# %%
# Create Classification version of target variable
wine1['goodquality'] = [1 if x >= 7 else 0 for x in wine1['quality']]# Separate feature variables and target variable
X = wine1.drop(['quality','goodquality','type'], axis = 1)
Y = wine1['goodquality']

# %%
# See proportion of good vs bad wines
wine1['goodquality'].value_counts()
# Out:
# 0    5220
# 1    1277
# Name: goodquality, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    0
# 6493    0
# 6494    0
# 6495    0
# 6496    0
# Name: goodquality, Length: 6497, dtype: int64

# %% [markdown]
# # Feature Importance

# %%
#from sklearn.preprocessing import LabelEncoder

#cat_columns = ['type']

# create an instance of the LabelEncoder class
#le = LabelEncoder()

# encode the categorical columns
#for col in cat_columns:
    #wine[col] = le.fit_transform(wine[col])

# display the encoded dataset
#print(wine.head())

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.07127719 0.08788058 0.07805792 0.08080019 0.08117659 0.07932311
#  0.07800694 0.10194543 0.07845203 0.08230304 0.18077698]

# %% [markdown]
# #  Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy Score: 0.8102564102564103

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[1496   51]
#  [ 319   84]]

# %% [markdown]
# # Using KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.7897435897435897

# %% [markdown]
# # Using SVC

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.7933333333333333

# %% [markdown]
# # Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8476923076923077

# %% [markdown]
# # Using GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.7497435897435898

# %% [markdown]
# # Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.8789743589743589

# %% [markdown]
# # Using Xgboost

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred5 = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred5))
# Out:
# Accuracy Score: 0.8676923076923077

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN', 'SVC','Decision Tree' ,'GaussianNB','Random Forest','Xgboost'],
    'Score': [0.810,0.789,0.793, 0.847,0.749,0.878,0.867]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 0.878        Random Forest
# 0.867              Xgboost
# 0.847        Decision Tree
# 0.810  Logistic Regression
# 0.793                  SVC
# 0.789                  KNN
# 0.749           GaussianNB
